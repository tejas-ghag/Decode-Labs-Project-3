# %%
import pandas as pd

# %%
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")

# %% [markdown]
# ### TASK 1 : Understanding the Dataset

# %%
print("First 5 Rows:")
print(df.head())

print("\nDataset Info:")
print(df.info())

print("\nDataset Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns)
